# %%
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../../data/processed/data_test_eda.csv")

# %%
df.head()
# Out:
#      Age  Gender         Education Country    Ethnicity   Nscore   Escore  \
# 0  35-44       0           diploma      uk  white-asian  0.31287 -0.57545
# 1  25-34       1  doctorate_degree      uk        white -0.67825  1.93886
# 2  35-44       1           diploma      uk        white -0.46725  0.80523
# 3  18-24       0    masters_degree      uk        white -0.14882 -0.80615
# 4  35-44       0  doctorate_degree      uk        white  0.73545 -1.63340
#
#     Oscore   Ascore   Cscore  Impulsive       SS  Alcohol  Amphet  Amyl  \
# 0 -0.58331 -0.91699 -0.00665   -0.21712 -1.18084        5       2     0
# 1  1.43533  0.76096 -0.14277   -0.71126 -0.21575        5       2     2
# 2 -0.84732 -1.62090 -1.01450   -1.37983  0.40148        6       0     0
# 3 -0.01928  0.59042  0.58489   -1.37983 -1.18084        4       0     0
# 4 -0.45174 -0.30172  1.30612   -0.21712 -0.21575        4       1     1
#
#    Benzos  Caff  Cannabis  Choc  Coke  Crack  Ecstasy  Heroin  Ketamine  \
# ...
